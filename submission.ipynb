# %% [markdown]
# # MDP ideas for decision theory 2024
# by: Yordan Mitev & Vladislav Stefanov
#
# # Snake
#
# In snake, the player controls the head of a hypothetical snake that lives on a grid of squares, and is aiming to eat fruit, get longer, and avoid hitting walls and its body. It can be steered left, right, up, and down to avoid the obstacles. Fruit appears randomly in a square that is not occupied currently by the snake's body. The more fruit you have eaten, in the least amount of moves, the higher your score.
#
# ![Snake Game](https://upload.wikimedia.org/wikipedia/commons/5/55/Snake_can_be_completed.gif)
#
# ## Starting conditions:
# - The fruit is put on a random square
# - The snake starts with a head and 2 blocks to denote its body
#
# ## Environment is constructed out of:
# - Playing field
# - Walls
#
# ## State is constructed out of:
# - Position of head
# - Area occupied by the body
# - Position of fruit
#
# ## The possible actions are:
# - `Move Left`
# - `Move Right`
# - `Move Up`
# - `Move Down`
#
# With just 3 of the actions possible at all times, because you can not steer back into yourself.
#
# ## Reward will be:
# - punishment for hitting the wall or itself (ends the episode)
# - reward for getting the fruit
# - huge reward for entering terminal state
#
# ## Terminal states:
# - `Positive`: when the snake's body + head fill up the whole playing field
# - `Negative`: when the snake collides with the wall or itself (ends the episode)
#
# # Connect4
#
# Connect4 is a game in which 2 players choose a color (yellow and red) and then take turns
# dropping colored tokens into a six-row, seven-column vertically suspended grid.
# The pieces fall straight down, occupying the lowest available space within the
# column. The objective of the game is to be the first to form a horizontal, vertical,
# or diagonal line of four of one's own tokens.
#
# Connect Four is a solved game. The first player can always win by playing the right moves.
#
# ![Connect4 Game](https://user-images.githubusercontent.com/39765499/56462040-26ef7080-63b4-11e9-8f5a-7f0b4dec216d.gif)
#
# ## Starting conditions:
# - Empty playing field (6 rows by 7 columns), with the yellow color being first
#
# ## Environment will be constructed out of:
# - Playing field
#
# ## State is constructed out of:
# - Your tokens' positions
# - Enemy tokens' positions
# - Whose turn is it to play
#
# ## The possible actions are:
# - `Release token in a not already full column`
#
# ## Reward will be:
# - `Negative` reward when the opponent enters terminal state
# - `Positive` reward when you enter terminal state
#
# ## Terminal states:
# The terminal state will be when either player achieves a column, row, or diagonal consisting
# of 4 or more tokens of this player's color.
#
# # Sokoban
#
# Sokoban is a puzzle video game in which the player pushes boxes around in a warehouse,
# trying to get them to storage locations.
#
# The warehouse is depicted as a grid of squares, each one representing either a floor
# section or a wall section. Some floor squares contain boxes and some are marked as
# storage locations. The player, often represented as a worker character, can move one
# square at a time horizontally or vertically onto empty floor squares, but cannot pass
# through walls or boxes.
#
# To move a box, the player walks up to it and pushes it to the square beyond. Boxes
# cannot be pushed to squares with walls or other boxes, and they cannot be pulled.
# The number of boxes matches the number of storage locations. The puzzle is solved
# when all boxes occupy the storage locations.
#
# ![Sokoban game](https://upload.wikimedia.org/wikipedia/commons/4/4b/Sokoban_ani.gif)
#
# ## Starting conditions:
# - The boxes and player are put in a specific position based on a puzzle
#
# ## Environment will be constructed out of:
# - Playing field
#
# ## State is constructed out of:
# - Position of the player
# - Position of the boxes
# - Position of the end markers
#
# ## The possible actions are:
# - `Move Left`
# - `Move Right`
# - `Move Up`
# - `Move Down`
#
# ## Reward will be:
# - `Negative` reward when the agent puts the box in unsolvable position (immovable and is not in an end spot)
# - `Positive` reward when the agent enters Positive Terminal state
#
# ## Terminal states:
# - `Positive`: If all boxes are in an end spot
# - `Negative`: If a box enters in a state that will make it immovable and is not in an end spot
#
#
# # Contributions:
#
# Initial list of ideas: 11 ideas
# Yordan: set up the repository, gave some of the ideas, and wrote the submission together with Vladislav.
# Vladislav: I brainstormed ideas, asked the teacher for feedback, discussed concepts and alternative solutions with Yordan and participated in the process of writing the document.
#
# 9 Hours per person
#
# # References:
#
# https://en.wikipedia.org/wiki/Snake_(video_game_genre)
#
# https://en.wikipedia.org/wiki/Connect_Four
#
# https://papergames.io/en/connect4
#
# https://web.mit.edu/sp.268/www/2010/connectFourSlides.pdf
#
# https://en.wikipedia.org/wiki/Sokoban
#
# https://www.sokobanonline.com/
